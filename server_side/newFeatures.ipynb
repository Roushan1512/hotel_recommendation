# %%
import pandas as pd

df=pd.read_csv("Hotel_Reviews.csv")

# %%
df.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
# 3      United Kingdom    My room was dirty and I was afraid to walk ba...
# 4         New Zealand    You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Hotel_Address    515738 non-null  object
#  1   Average_Score    515738 non-null  float64
#  2   Hotel_Name       515738 non-null  object
#  3   Positive_Review  515738 non-null  object
#  4   Reviewer_Score   515738 non-null  float64
#  5   Tags             515738 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 23.6+ MB

# %%
df.drop(["Additional_Number_of_Scoring","Review_Date","Reviewer_Nationality","Negative_Review","Review_Total_Negative_Word_Counts","Total_Number_of_Reviews","Review_Total_Positive_Word_Counts","Total_Number_of_Reviews_Reviewer_Has_Given","days_since_review","lat","lng"],axis=1,inplace=True)

# %%
df.Hotel_Address = df.Hotel_Address.str.replace("Netherlands","NL")
df.Hotel_Address = df.Hotel_Address.str.replace("United Kingdom","UK")
df.Hotel_Address = df.Hotel_Address.str.replace("France","FR")
df.Hotel_Address = df.Hotel_Address.str.replace("Spain","ES")
df.Hotel_Address = df.Hotel_Address.str.replace("Italy","IT")
df.Hotel_Address = df.Hotel_Address.str.replace("Austria","AT")

df["countries"] = df.Hotel_Address.apply(lambda x : x.split(" ")[-1])

# %%
df["Positive_Review"]=df["Positive_Review"].apply(lambda x: x.lower())

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from ast import literal_eval
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ROUSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ROUSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ROUSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ROUSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def taglist(column):
    column=column[0]
    if(type(column) != list):
        return "".join(literal_eval(column))
    else:
        return column

df["Tags"]=df[["Tags"]].apply(taglist,axis=1)
df["Tags"]=df["Tags"].apply(lambda x: x.lower())
# Out:
# C:\Users\ROUSHAN\AppData\Local\Temp\ipykernel_6856\3676961512.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   column=column[0]

# %%
import pickle

pickle.dump(df,open("hotelModel2.pkl","wb"))

# %%
import pickle

hotelData=pickle.load(open("hotelModel2.pkl","rb"))
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                    Positive_Review  \
# 0  Hotel Arena   only the park outside of the hotel was beauti...
# 1  Hotel Arena   no real complaints the hotel was great great ...
# 2  Hotel Arena   location was good and staff were ok it is cut...
# 3  Hotel Arena   great location in nice surroundings the bar a...
# 4  Hotel Arena    amazing location and building romantic setting
#
#    Reviewer_Score                                               Tags countries
# 0             2.9   leisure trip  couple  duplex double room  sta...        NL
# 1             7.5   leisure trip  couple  duplex double room  sta...        NL
# 2             7.1   leisure trip  family with young children  dup...        NL
# 3             3.8   leisure trip  solo traveler  duplex double ro...        NL
# 4             6.7   leisure trip  couple  suite  stayed 2 nights ...        NL

# %%
import pickle

hotelPrevData=pickle.load(open("hotelModelPickle.pkl","rb"))
hotelPrevData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags countries  \
# 0  Hotel Arena   leisure trip  couple  duplex double room  sta...        NL
# 1  Hotel Arena   leisure trip  couple  duplex double room  sta...        NL
# 2  Hotel Arena   leisure trip  family with young children  dup...        NL
# 3  Hotel Arena   leisure trip  solo traveler  duplex double ro...        NL
# 4  Hotel Arena   leisure trip  couple  suite  stayed 2 nights ...        NL
#
#    Stars  Word_Score  Price
# 0      5        6.05   1470
# 1      5        2.83   1470
# 2      5        6.98   1470
# 3      5        3.84   1470
# 4      5        8.89   1470

# %%
hotelData["Stars"]=hotelPrevData["Stars"]

# %%
hotelData["Price"]=hotelPrevData["Price"]

# %%
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#    Reviewer_Score   Hotel_Name  \
# 0             2.9  Hotel Arena
# 1             7.5  Hotel Arena
# 2             7.1  Hotel Arena
# 3             3.8  Hotel Arena
# 4             6.7  Hotel Arena
#
#                                      Positive_Review  \
# 0   only the park outside of the hotel was beauti...
# 1   no real complaints the hotel was great great ...
# 2   location was good and staff were ok it is cut...
# 3   great location in nice surroundings the bar a...
# 4    amazing location and building romantic setting
#
#                                                 Tags  \
# 0   leisure trip  couple  duplex double room  sta...
# 1   leisure trip  couple  duplex double room  sta...
# 2   leisure trip  family with young children  dup...
# 3   leisure trip  solo traveler  duplex double ro...
# 4   leisure trip  couple  suite  stayed 2 nights ...
#
#                                                Words countries  Stars  Price
# 0   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 1   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 2   leisure trip  family with young children  dup...        NL      5   1470
# 3   leisure trip  solo traveler  duplex double ro...        NL      5   1470
# 4   leisure trip  couple  suite  stayed 2 nights ...        NL      5   1470

# %%
hotelData.insert(2,'Reviewer_Score',hotelData.pop('Reviewer_Score'))

# %%
hotelData['Words']=hotelData['Tags']+" "+hotelData['Positive_Review']

# %%
hotelData.insert(6,'Words',hotelData.pop('Words'))

# %%
hotelPrevData.iloc[[351956,284676,255526,482429,72957]]
# Out:
#                                             Hotel_Address  Average_Score  \
# 351956  Josefst dter Stra e 10 12 08 Josefstadt 1080 V...            8.3
# 284676      Bellamyplein 47 Oud West 1053 AT Amsterdam NL            8.8
# 255526  84 King Street Hammersmith and Fulham London W...            7.8
# 482429                    Via Mecenate 121 20138 Milan IT            8.0
# 72957   173 Gloucester Place Westminster Borough Londo...            7.7
#
#                                            Hotel_Name  \
# 351956            Fleming s Selection Hotel Wien City
# 284676                                Hotel De Hallen
# 255526  Best Western Plus Seraphine Hammersmith Hotel
# 482429                Novotel Milano Linate Aeroporto
# 72957                        Park Avenue Baker Street
#
#                                                      Tags countries  Stars  \
# 351956   leisure trip  couple  superior double or twin...        AT      4
# 284676   leisure trip  family with older children  dou...        NL      3
# 255526   business trip  solo traveler  executive doubl...        UK      4
# 482429   leisure trip  group  superior room with 1 dou...        IT      3
# 72957    leisure trip  solo traveler  deluxe double ro...        UK      4
#
#         Word_Score  Price
# 351956        2.53    730
# 284676        3.58    350
# 255526        5.09    880
# 482429        7.60    240
# 72957         4.27    650

# %%
import pickle

pickle.dump(hotelData,open("hotelModel2.pkl","wb"))

# %%
import pickle

hotelData=pickle.load(open("hotelModel2.pkl","rb"))
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#    Reviewer_Score   Hotel_Name  \
# 0             2.9  Hotel Arena
# 1             7.5  Hotel Arena
# 2             7.1  Hotel Arena
# 3             3.8  Hotel Arena
# 4             6.7  Hotel Arena
#
#                                      Positive_Review  \
# 0   only the park outside of the hotel was beauti...
# 1   no real complaints the hotel was great great ...
# 2   location was good and staff were ok it is cut...
# 3   great location in nice surroundings the bar a...
# 4    amazing location and building romantic setting
#
#                                                 Tags  \
# 0   leisure trip  couple  duplex double room  sta...
# 1   leisure trip  couple  duplex double room  sta...
# 2   leisure trip  family with young children  dup...
# 3   leisure trip  solo traveler  duplex double ro...
# 4   leisure trip  couple  suite  stayed 2 nights ...
#
#                                                Words countries  Stars  Price  \
# 0   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 1   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 2   leisure trip  family with young children  dup...        NL      5   1470
# 3   leisure trip  solo traveler  duplex double ro...        NL      5   1470
# 4   leisure trip  couple  suite  stayed 2 nights ...        NL      5   1470
#
#                                Amenities ReviewDate  isRecent
# 0  [Air Conditioning, Fine Dining, Wifi] 2017-08-03      True
# 1  [Air Conditioning, Fine Dining, Wifi] 2017-08-03      True
# 2  [Air Conditioning, Fine Dining, Wifi] 2017-07-31      True
# 3  [Air Conditioning, Fine Dining, Wifi] 2017-07-31      True
# 4  [Air Conditioning, Fine Dining, Wifi] 2017-07-24      True

# %%
import pandas as pd
import nltk            #natural language
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def findMyHotel4(df, country, sortBy, stars, range, query):

    #country
    countryMask=df["countries"].str.contains(country,case=False)

    #stars
    starMask=pd.Series([True]*len(df))
    if stars!=0:
        if stars==3:
            starMask=df['Stars']==3
        elif stars==4:
            starMask=df['Stars']==4
        elif stars==5:
            starMask=df['Stars']==5

    
    #price
    min=range[0]
    max=range[1]
    minPriceMask=df['Price']>=min
    maxPriceMask=df['Price']<=max
    combinedPriceMask=minPriceMask & maxPriceMask

    #filter
    filterDf=df[countryMask & starMask & combinedPriceMask]
    filterDf=filterDf.drop_duplicates(['Hotel_Name'])

    #process text
    def processText(text):
        stopWords=set(stopwords.words("english"))
        words=word_tokenize(text)
        filterWords=[i for i in words if i not in stopWords]
        lemmat=WordNetLemmatizer()
        lemmatWords=[lemmat.lemmatize(i) for i in filterWords]
        return " ".join(lemmatWords)
    
    #processing the query
    queryText=processText(query)

    #creating the vectors and finding cos product
    tfidf=TfidfVectorizer(stop_words="english")
    tfMatrix=tfidf.fit_transform(filterDf['Words'])
    queryVector=tfidf.transform([queryText.lower()])
    cosProd=cosine_similarity(queryVector,tfMatrix).flatten()
    hotelsFound=cosProd.argsort()[-100:][::-1]
    resultDf=filterDf.iloc[hotelsFound]

    if sortBy==0:
        resultDf=resultDf.sort_values('Average_Score',ascending=False)
    elif sortBy==1:
        resultDf=resultDf.sort_values('Reviewer_Score',ascending=False)
    elif sortBy==2:
        resultDf=resultDf.sort_values('Price',ascending=True)
    else:
        print("Wrong filter")
        return
    
    resultDf=resultDf.head(5)
    return resultDf

findMyHotel4(hotelData,"UK",2,5,[1200,1500],"single bed couple room")
# Out:
#                                             Hotel_Address  Average_Score  \
# 132593  291 Greenwich High Road Greenwich Greenwich Lo...            8.2
# 54026   15 Cromwell Place Kensington and Chelsea Londo...            8.6
# 240501  7 Western Gateway Royal Victoria Dock Newham L...            8.5
# 70751   17 Nottingham Place Westminster Borough London...            7.6
# 971     1 2 Serjeant s Inn Fleet Street City of London...            9.2
#
#         Reviewer_Score                          Hotel_Name  \
# 132593             7.9  Innkeeper s Lodge London Greenwich
# 54026             10.0    The Pelham Starhotels Collezione
# 240501             9.2                Novotel London Excel
# 70751              4.6                      Hotel La Place
# 971                9.2             Apex Temple Court Hotel
#
#                                           Positive_Review  \
# 132593   fantastic location opposite greenwich market ...
# 54026    this was in a great location museums on the c...
# 240501                                        no positive
# 70751    good access to tube could leave luggage there...
# 971      they have followed through special requests c...
#
#                                                      Tags  \
# 132593   leisure trip  couple  standard double room  s...
# 54026    leisure trip  group  deluxe double or twin ro...
# 240501   leisure trip  group  standard queen room with...
# 70751    leisure trip  solo traveler  single room  sta...
# 971      leisure trip  couple  deluxe king room with c...
#
#                                                     Words countries  Stars  \
# 132593   leisure trip  couple  standard double room  s...        UK      5
# 54026    leisure trip  group  deluxe double or twin ro...        UK      5
# 240501   leisure trip  group  standard queen room with...        UK      5
# 70751    leisure trip  solo traveler  single room  sta...        UK      5
# 971      leisure trip  couple  deluxe king room with c...        UK      5
#
#         Price                         Amenities ReviewDate  isRecent
# 132593   1210   [Swimming Pool, Spa, Wifi, Gym] 2017-08-02      True
# 54026    1210                [Fine Dining, Spa] 2017-07-27      True
# 240501   1220                       [Spa, Wifi] 2017-08-03      True
# 70751    1220  [Spa, Parking, Gym, Fine Dining] 2017-08-01      True
# 971      1230           [Room Service, Parking] 2017-08-02      True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

def processText(text):
    stopWords=set(stopwords.words("english"))
    words=word_tokenize(text)
    filterWords=[i for i in words if i not in stopWords]
    lemmat=WordNetLemmatizer()
    lemmatWords=[lemmat.lemmatize(i) for i in filterWords]
    return " ".join(lemmatWords)

# %%
text=processText("i am going on a business trip and want a couple room")
print(text)
# Out:
# going business trip want couple room

# %%
hotelData['Words']=hotelData['Words'].apply(processText)

# %%
import random
i=random.randint(0,len(hotelData))
print("Tags: ")
print(hotelData['Tags'][i])
print("Positive Review")
print(hotelData['Positive_Review'][i])
print("Amenities")
print(hotelData["Amenities"][i])
print("Words")
print(hotelData['Words'][i])
# Out:
# Tags:
#  leisure trip  couple  standard double room  stayed 1 night
# Positive Review
#  very good we arrived early and the room was ready so we could leave our cases
# Amenities
# ['Parking', 'Spa']
# Words
#  leisure trip  couple  standard double room  stayed 1 night  parking spa

# %%
allHotels=[]

for i in hotelData['Hotel_Name']:
    if i not in allHotels:
        allHotels.append(i)

print(allHotels)
# Out:
# ['Hotel Arena', 'K K Hotel George', 'Apex Temple Court Hotel', 'The Park Grand London Paddington', 'Monhotel Lounge SPA', 'Kube Hotel Ice Bar', 'The Principal London', 'Park Plaza County Hall London', 'One Aldwych', 'Splendid Etoile', 'Hotel Trianon Rive Gauche', 'InterContinental London Park Lane', 'Novotel Suites Paris Nord 18 me', 'Grand Royale London Hyde Park', 'Milestone Hotel Kensington', 'Crowne Plaza London Kings Cross', 'Select Hotel', 'H tel De Vend me', 'Pullman Paris Centre Bercy', 'Gardette Park Hotel', 'Hotel Panache', 'H tel des Ducs D Anjou', 'Hotel Scribe Paris Opera by Sofitel', 'Novotel London West', 'Haymarket Hotel', 'Intercontinental London The O2', 'H tel Juliana Paris', 'Hotel L Antoine', 'Belfast', 'Shangri La Hotel Paris', 'Mercure Paris Tour Eiffel Pont Mirabeau', 'Knightsbridge Hotel', 'The London EDITION', 'The Cranley Hotel', 'Hotel Le 10 BIS', 'The Nadler Soho', 'Grange St Paul s Hotel', 'The Ampersand Hotel', 'Covent Garden Hotel', 'The Nadler Victoria', 'Novotel London Tower Bridge', 'Crowne Plaza Paris R publique', 'Le Metropolitan a Tribute Portfolio Hotel', 'Atala Champs Elys es', 'H tel de Jos phine BONAPARTE', 'Maison Souquet', 'Hotel Tour d Auvergne Opera', 'Le Senat', 'Windsor Opera', 'Holiday Inn Paris Montparnasse Pasteur', 'H tel Keppler', 'Les Plumes Hotel', 'Hotel des Tuileries Relais du Silence', 'Bradford Elys es Astotel', 'W London Leicester Square', 'The Victoria', 'Pullman London St Pancras', 'Crowne Plaza London Kensington', 'Doubletree by Hilton London Kensington', 'Ace Hotel London Shoreditch', 'Staybridge Suites London Vauxhall', 'The Grosvenor', 'The Park Tower Knightsbridge a Luxury Collection Hotel', 'Amp re', 'Melia Paris Champs Elys es', 'Le Parisis Paris Tour Eiffel', 'Thistle Kensington Gardens', 'Park Plaza Sherlock Holmes London', 'Hilton Paris Opera', 'The Kensington Hotel', 'Holiday Inn London Stratford City', 'Staybridge Suites London Stratford', 'Shepherd s Bush Boutique Hotel', 'My Bloomsbury', 'Holiday Inn Paris Gare de Lyon Bastille', 'H tel Chaplain Paris Rive Gauche', 'H tel Regina Op ra Grands Boulevards', '11 Cadogan Gardens', 'The Wellesley Knightsbridge a Luxury Collection Hotel London', 'Hotel Astor Saint Honor ', 'Op ra Marigny', 'H tel Diva Opera', 'Le Marcel', 'H tel Duo', 'H tel Le Marianne', 'The Rembrandt', 'Hotel Eden', 'H tel de la Bourdonnais', 'Ashburn Hotel', 'Marlin Waterloo', 'Best Western Premier Marais Grands Boulevards', 'Novotel London Waterloo', 'The Athenaeum', 'Park International Hotel', 'Lansbury Heritage Hotel', 'Le Dokhan s a Tribute Portfolio Hotel', 'Le Relais Madeleine', 'Terrass H tel Montmartre by MH', 'Millennium Hotel Paris Opera', 'Waldorf Madeleine', 'Batty Langley s', 'Best Western Mornington Hotel Hyde Park', 'Arbor City', 'Hotel La Lanterne', 'H tel Square Louvois', 'Hotel Marignan Champs Elys es', 'Le Grey Hotel', 'Le Pavillon des Lettres', 'H tel San R gis', 'Garden Elys e', 'Hotel Louvre Montana', 'Ambassadors Bloomsbury', 'Le 123 S bastopol Astotel', 'Le 123 Elysees Astotel', 'The Bryson Hotel', 'Best Western Mercedes Arc de Triomphe', 'London Marriott Hotel Regents Park', 'Hilton London Hyde Park', 'Staunton Hotel B B', '1K Hotel', 'H tel Westminster', 'L H tel', 'Mercure Paris Porte d Orleans', 'Maxim Op ra', 'Le Marceau Bastille', 'Hotel Odeon Saint Germain', 'Mercure London Bloomsbury Hotel', 'The Chamberlain', 'Radisson Blu Edwardian Grafton', 'La Villa Haussmann', 'London Marriott Hotel Marble Arch', 'Saint Georges Hotel', 'Park Grand London Lancaster Gate', 'The Henrietta Hotel', 'Sofitel Paris Arc De Triomphe', 'Hotel Mercure La Sorbonne Saint Germain des Pr s', 'La Tremoille Paris', 'Hotel Op ra Richepanse', 'H tel Duc De St Simon', 'Hotel Le Six', 'The Bailey s Hotel London', 'London Marriott Hotel Park Lane', 'Best Western Premier Louvre Saint Honor ', 'Hotel Indigo London Tower Hill', 'Windermere Hotel', 'La Villa Maillot', 'H tel Madison by MH', 'Mercure London Paddington Hotel', 'Hilton London Padd ...

# %%
amenities=["Wifi","TV","Air Conditioning","Room Service","Gym","Swimming Pool","Parking","Fine Dining","BathTub","Spa"]
print(len(amenities))
# Out:
# 10

# %%
import random

def randomAmen():
    n=random.randint(2,5)
    randomAmenities=random.sample(amenities,n)
    return randomAmenities

print(randomAmen())
# Out:
# ['Spa', 'Fine Dining']

# %%
hotelAmen={}

for i in allHotels:
    hotelAmen[i]=randomAmen()

print(hotelAmen)
# Out:
# {'Hotel Arena': ['Air Conditioning', 'Fine Dining', 'Wifi'], 'K K Hotel George': ['BathTub', 'Air Conditioning'], 'Apex Temple Court Hotel': ['Room Service', 'Parking'], 'The Park Grand London Paddington': ['BathTub', 'Spa', 'Fine Dining', 'TV', 'Wifi'], 'Monhotel Lounge SPA': ['Air Conditioning', 'Fine Dining'], 'Kube Hotel Ice Bar': ['Parking', 'Wifi', 'Fine Dining', 'Spa', 'Gym'], 'The Principal London': ['BathTub', 'Room Service', 'Spa'], 'Park Plaza County Hall London': ['Room Service', 'Swimming Pool', 'BathTub', 'Gym'], 'One Aldwych': ['Air Conditioning', 'Swimming Pool', 'Parking', 'Wifi'], 'Splendid Etoile': ['BathTub', 'TV', 'Wifi', 'Gym'], 'Hotel Trianon Rive Gauche': ['Gym', 'Swimming Pool'], 'InterContinental London Park Lane': ['Gym', 'Room Service', 'TV'], 'Novotel Suites Paris Nord 18 me': ['Room Service', 'TV'], 'Grand Royale London Hyde Park': ['Parking', 'Wifi', 'Gym', 'Air Conditioning'], 'Milestone Hotel Kensington': ['BathTub', 'Parking'], 'Crowne Plaza London Kings Cross': ['Parking', 'Gym', 'Fine Dining', 'TV', 'Air Conditioning'], 'Select Hotel': ['Spa', 'Gym', 'BathTub'], 'H tel De Vend me': ['Parking', 'TV', 'Wifi'], 'Pullman Paris Centre Bercy': ['Fine Dining', 'BathTub', 'Spa', 'Parking'], 'Gardette Park Hotel': ['Parking', 'Air Conditioning', 'Gym', 'Room Service', 'TV'], 'Hotel Panache': ['Swimming Pool', 'Room Service', 'BathTub', 'Gym', 'Wifi'], 'H tel des Ducs D Anjou': ['Fine Dining', 'Parking'], 'Hotel Scribe Paris Opera by Sofitel': ['Room Service', 'TV', 'Air Conditioning', 'Gym', 'Fine Dining'], 'Novotel London West': ['Parking', 'Spa', 'Fine Dining', 'Air Conditioning'], 'Haymarket Hotel': ['Room Service', 'Gym'], 'Intercontinental London The O2': ['Spa', 'Wifi', 'Room Service'], 'H tel Juliana Paris': ['Swimming Pool', 'Gym', 'Fine Dining', 'BathTub', 'Air Conditioning'], 'Hotel L Antoine': ['BathTub', 'Spa'], 'Belfast': ['TV', 'Wifi', 'Swimming Pool'], 'Shangri La Hotel Paris': ['Fine Dining', 'Gym'], 'Mercure Paris Tour Eiffel Pont Mirabeau': ['Fine Dining', 'Swimming Pool'], 'Knightsbridge Hotel': ['Room Service', 'Parking'], 'The London EDITION': ['Fine Dining', 'Parking', 'Room Service'], 'The Cranley Hotel': ['Room Service', 'Parking', 'BathTub', 'TV'], 'Hotel Le 10 BIS': ['TV', 'Spa', 'Parking', 'Room Service', 'Wifi'], 'The Nadler Soho': ['TV', 'Wifi', 'Fine Dining', 'Gym', 'Air Conditioning'], 'Grange St Paul s Hotel': ['TV', 'Wifi', 'Parking', 'Fine Dining', 'Spa'], 'The Ampersand Hotel': ['Fine Dining', 'Air Conditioning', 'BathTub'], 'Covent Garden Hotel': ['Air Conditioning', 'Room Service', 'Parking', 'TV', 'Wifi'], 'The Nadler Victoria': ['Fine Dining', 'Wifi', 'Spa'], 'Novotel London Tower Bridge': ['Air Conditioning', 'Swimming Pool', 'TV'], 'Crowne Plaza Paris R publique': ['TV', 'Wifi'], 'Le Metropolitan a Tribute Portfolio Hotel': ['Air Conditioning', 'Gym', 'Wifi', 'TV'], 'Atala Champs Elys es': ['Spa', 'BathTub', 'Gym', 'Wifi', 'Fine Dining'], 'H tel de Jos phine BONAPARTE': ['Fine Dining', 'Parking', 'Wifi', 'TV'], 'Maison Souquet': ['Parking', 'Air Conditioning', 'Wifi', 'Spa'], 'Hotel Tour d Auvergne Opera': ['Wifi', 'TV', 'BathTub'], 'Le Senat': ['Gym', 'Room Service', 'Swimming Pool', 'Fine Dining', 'Air Conditioning'], 'Windsor Opera': ['Air Conditioning', 'Spa', 'Fine Dining', 'Wifi', 'Swimming Pool'], 'Holiday Inn Paris Montparnasse Pasteur': ['Room Service', 'Gym', 'Parking', 'BathTub', 'Fine Dining'], 'H tel Keppler': ['Air Conditioning', 'BathTub', 'Fine Dining', 'Gym'], 'Les Plumes Hotel': ['Gym', 'Fine Dining', 'BathTub', 'Parking', 'TV'], 'Hotel des Tuileries Relais du Silence': ['Wifi', 'Gym', 'TV', 'Parking'], 'Bradford Elys es Astotel': ['Room Service', 'Gym', 'BathTub', 'Fine Dining'], 'W London Leicester Square': ['Room Service', 'Wifi', 'Parking', 'Air Conditioning', 'TV'], 'The Victoria': ['BathTub', 'Air Conditioning', 'Swimming Pool', 'Spa'], 'Pullman London St Pancras': ['Gym', 'Room Service'], 'Crowne Plaza London Kensington': ['Gym', 'Room ...

# %%
hotelData['Amenities']=hotelData['Hotel_Name'].map(hotelAmen)

# %%
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#    Reviewer_Score   Hotel_Name  \
# 0             2.9  Hotel Arena
# 1             7.5  Hotel Arena
# 2             7.1  Hotel Arena
# 3             3.8  Hotel Arena
# 4             6.7  Hotel Arena
#
#                                      Positive_Review  \
# 0   only the park outside of the hotel was beauti...
# 1   no real complaints the hotel was great great ...
# 2   location was good and staff were ok it is cut...
# 3   great location in nice surroundings the bar a...
# 4    amazing location and building romantic setting
#
#                                                 Tags  \
# 0   leisure trip  couple  duplex double room  sta...
# 1   leisure trip  couple  duplex double room  sta...
# 2   leisure trip  family with young children  dup...
# 3   leisure trip  solo traveler  duplex double ro...
# 4   leisure trip  couple  suite  stayed 2 nights ...
#
#                                                Words countries  Stars  Price  \
# 0   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 1   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 2   leisure trip  family with young children  dup...        NL      5   1470
# 3   leisure trip  solo traveler  duplex double ro...        NL      5   1470
# 4   leisure trip  couple  suite  stayed 2 nights ...        NL      5   1470
#
#                                Amenities ReviewDate
# 0  [Air Conditioning, Fine Dining, Wifi] 2017-08-03
# 1  [Air Conditioning, Fine Dining, Wifi] 2017-08-03
# 2  [Air Conditioning, Fine Dining, Wifi] 2017-07-31
# 3  [Air Conditioning, Fine Dining, Wifi] 2017-07-31
# 4  [Air Conditioning, Fine Dining, Wifi] 2017-07-24

# %%
hotelData['AmenList']=hotelData['Amenities'].apply(lambda i : " ".join(i))
hotelData['AmenList']=hotelData['AmenList'].apply(lambda i : i.lower())

# %%
hotelData['Words']=hotelData['Tags']+" "+hotelData['AmenList']

# %%
hotelData.drop("AmenList",axis=1,inplace=True)

# %%
import pandas as pd

df=pd.read_csv("Hotel_Reviews.csv")

# %%
df.sample()
# Out:
#                                             Hotel_Address  \
# 283965  Belgrove Street Camden London WC1H 8AB United ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score    Hotel_Name  \
# 283965                           392  12/31/2015            8.8  Megaro Hotel
#
#        Reviewer_Nationality Negative_Review  \
# 283965      United Kingdom      No Negative
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 283965                                  0                     1803
#
#                                           Positive_Review  \
# 283965   We stayed here twice in December before and a...
#
#         Review_Total_Positive_Word_Counts  \
# 283965                                 34
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 283965                                          13             9.2
#
#                                                      Tags days_since_review  \
# 283965  [' Leisure trip ', ' Couple ', ' Deluxe Double...           581 day
#
#               lat       lng
# 283965  51.529441 -0.123374

# %%
hotelData["ReviewDate"]=df['Review_Date']

# %%
hotelData['ReviewDate']=pd.to_datetime(hotelData['ReviewDate'])

# %%
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#    Reviewer_Score   Hotel_Name  \
# 0             2.9  Hotel Arena
# 1             7.5  Hotel Arena
# 2             7.1  Hotel Arena
# 3             3.8  Hotel Arena
# 4             6.7  Hotel Arena
#
#                                      Positive_Review  \
# 0   only the park outside of the hotel was beauti...
# 1   no real complaints the hotel was great great ...
# 2   location was good and staff were ok it is cut...
# 3   great location in nice surroundings the bar a...
# 4    amazing location and building romantic setting
#
#                                                 Tags  \
# 0   leisure trip  couple  duplex double room  sta...
# 1   leisure trip  couple  duplex double room  sta...
# 2   leisure trip  family with young children  dup...
# 3   leisure trip  solo traveler  duplex double ro...
# 4   leisure trip  couple  suite  stayed 2 nights ...
#
#                                                Words countries  Stars  Price  \
# 0   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 1   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 2   leisure trip  family with young children  dup...        NL      5   1470
# 3   leisure trip  solo traveler  duplex double ro...        NL      5   1470
# 4   leisure trip  couple  suite  stayed 2 nights ...        NL      5   1470
#
#                                Amenities ReviewDate
# 0  [Air Conditioning, Fine Dining, Wifi] 2017-08-03
# 1  [Air Conditioning, Fine Dining, Wifi] 2017-08-03
# 2  [Air Conditioning, Fine Dining, Wifi] 2017-07-31
# 3  [Air Conditioning, Fine Dining, Wifi] 2017-07-31
# 4  [Air Conditioning, Fine Dining, Wifi] 2017-07-24

# %%
import pickle

pickle.dump(hotelData,open("hotelModel2.pkl","wb"))

# %%
import pandas as pd
import nltk            #natural language
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def findHotel(query):
    filterDf = hotelData.sort_values(['Reviewer_Score', 'Hotel_Name'], ascending=[False, True]).drop_duplicates('Hotel_Name',keep='first')
    #filterDf=hotelData.drop_duplicates('Hotel_Name',keep='first')

    #process text
    def processText(text):
        stopWords=set(stopwords.words("english"))
        words=word_tokenize(text)
        filterWords=[i for i in words if i not in stopWords]
        lemmat=WordNetLemmatizer()
        lemmatWords=[lemmat.lemmatize(i) for i in filterWords]
        return " ".join(lemmatWords)
    
    #processing the query
    queryText=processText(query)

    #creating the vectors and finding cos product
    tfidf=TfidfVectorizer(stop_words="english")
    tfMatrix=tfidf.fit_transform(filterDf['Words'])
    queryVector=tfidf.transform([queryText.lower()])
    cosProd=cosine_similarity(queryVector,tfMatrix).flatten()
    hotelsFound=cosProd.argsort()[-100:][::-1]
    resultDf=filterDf.iloc[hotelsFound]
    
    resultDf=resultDf.reset_index(drop=True)
    return resultDf['Hotel_Name']

hotelNames=findHotel("spacious couple room")
print(hotelNames)
# Out:
# 0                      Catalonia Catedral
# 1                        The Lanesborough
# 2                  IH Hotels Milano Gioia
# 3                          Catalonia Born
# 4                               Ozo Hotel
#                      ...
# 95                     Hotel Montalembert
# 96         Inntel Hotels Amsterdam Centre
# 97    Golden Tulip Bercy Gare de Lyon 209
# 98                   Rainers Hotel Vienna
# 99                             Park Hotel
# Name: Hotel_Name, Length: 100, dtype: object

# %%
allQueries1=["spacious","couple room","double bed","leisure trip","business trip","deluxe","spa","gym","fine dining","bathtub","clean room"]
allQueries2=["space","couple room","double bed","leisure trip","business","deluxe","spa","gym","dining","bathtub","clean"]
allQueries=[[x,y] for x,y in zip(allQueries1,allQueries2)]
print(allQueries[0][1])
# Out:
# space

# %%
truthHotels={}

for query in allQueries1:
    hotels=findHotel(query)
    truthHotels[query]=hotels

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.multioutput import ClassifierChain
from sklearn.svm import SVC
import numpy as np

yTrue=[]
yPred=[]

for i in allQueries:
    hotelsFound=findHotel(i[1])
    yTrue.extend(truthHotels[i[0]])
    yPred.extend(hotelsFound)

precision=precision_score(yTrue,yPred,average='weighted')
recall=recall_score(yTrue,yPred,average='weighted')
f1=f1_score(yTrue,yPred,average='weighted')

print("Precision : ",precision*100,"\nRecall : ",recall*100,"\nF1 Score : ",f1*100)
# Out:
# Precision :  92.2939393939394
# Recall :  90.0
# F1 Score :  89.69206349206348
# c:\Users\ROUSHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pickle

pickle.dump(truthHotels,open("truthHotels.pkl","wb"))

# %%
import pickle 

pickle.dump(allQueries,open("allQueries.pkl","wb"))

# %%
truthHotels=pickle.load(open("truthHotels.pkl","rb"))
allQueries=pickle.load(open("allQueries.pkl","rb"))
print(truthHotels)
print(allQueries)
# Out:
# {'spacious': 0                                    11 Cadogan Gardens
# 1                                         Hotel Liberty
# 2                   Ibis Styles Paris Gare Saint Lazare
# 3                                         Villa Eugenie
# 4                                 ADI Doria Grand Hotel
#                             ...
# 95                             The Westbourne Hyde Park
# 96                                 The Westbridge Hotel
# 97    The Westbury A Luxury Collection Hotel Mayfair...
# 98                                    The Westin Palace
# 99                             The Westin Paris Vend me
# Name: Hotel_Name, Length: 100, dtype: object, 'couple room': 0                      Catalonia Catedral
# 1                        The Lanesborough
# 2                  IH Hotels Milano Gioia
# 3                          Catalonia Born
# 4                               Ozo Hotel
#                      ...
# 95                     Hotel Montalembert
# 96         Inntel Hotels Amsterdam Centre
# 97    Golden Tulip Bercy Gare de Lyon 209
# 98                   Rainers Hotel Vienna
# 99                             Park Hotel
# Name: Hotel_Name, Length: 100, dtype: object, 'double bed': 0        Novotel Suites Paris Montreuil Vincennes
# 1                 Novotel Suites Paris Nord 18 me
# 2     Mercure Vaugirard Paris Porte De Versailles
# 3                      Pullman Paris Centre Bercy
# 4                Novotel Paris Centre Tour Eiffel
#                          ...
# 95                                   Vilana Hotel
# 96                                    Hotel Royal
# 97                             Royal Saint Michel
# 98                          UNA Hotel Scandinavia
# 99                               The Corner Hotel
# Name: Hotel_Name, Length: 100, dtype: object, 'leisure trip': 0                 Hotel K nig von Ungarn
# 1                             My Chelsea
# 2                      The Tophams Hotel
# 3                               Colombia
# 4                         Hotel Whistler
#                      ...
# 95              IH Hotels Milano Puccini
# 96    St Martins Lane A Morgans Original
# 97                        L Empire Paris
# 98                          Melia Vienna
# 99                      Victoire Germain
# Name: Hotel_Name, Length: 100, dtype: object, 'business trip': 0                         Villa Alessandra
# 1               Suite Hotel 900 m zur Oper
# 2                       The May Fair Hotel
# 3                         Relais Christine
# 4                          Hotel Raffaello
#                       ...
# 95                  The Marble Arch London
# 96                          Draycott Hotel
# 97               Four Seasons Hotel Milano
# 98                 Luxury Suites Amsterdam
# 99    Appartement Hotel an der Riemergasse
# Name: Hotel_Name, Length: 100, dtype: object, 'deluxe': 0                       Amsterdam Marriott Hotel
# 1                      Hotel Odeon Saint Germain
# 2                               The Lanesborough
# 3                          Hotel du Petit Moulin
# 4                   Petit Palais Hotel De Charme
#                          ...
# 95                            Royal Saint Honore
# 96                                      1K Hotel
# 97                          Bulgari Hotel London
# 98                          Adria Boutique Hotel
# 99    Montcalm Royal London House City of London
# Name: Hotel_Name, Length: 100, dtype: object, 'spa': 0                    Sall s Hotel Pere IV
# 1                           The Colonnade
# 2                      Catalonia Catedral
# 3     Golden Tulip Bercy Gare de Lyon 209
# 4                   Savoy Hotel Amsterdam
#                      ...
# 95                          H tel Le Walt
# 96        Sheraton Grand London Park Lane
# 97         Intercontinental London The O2
# 98                 Hotel Palais Strudlhof
# 99                     NH Sants Barcelona
# Name: Hotel_Name, Length: 100, dtype: object, 'gym': 0                     The Tophams Hotel
# 1                Mercure Milano Regency
# 2                    Olivia Plaza Hotel
# 3                Hotel degli Arcimboldi
# 4             Hotel Odeon Saint Germain
#                     ...
# 95       Shepherd s Bush Boutique Hotel
# 96    Park Plaza Sherlock Holmes London
# 97                   Hilton Paris Opera
# 98                Atlantis Hotel Vienna
# 99                  Das Opernring Hotel
# Name: Hotel_Name, Length: 100, dtype: object, 'fine dining': 0                               Hotel Whistler
# 1                          Carlyle Brera Hotel
# 2                              Newhotel Roblin
# 3                          Hotel Ronda Lesseps
# 4                           Hotel Montalembert
#                         ...
# 95                   Hotel Les Bulles De Paris
# 96              Hilton Garden Inn Vienna South
# 97    Best Western Premier Louvre Saint Honor
# 98                      Ambassadors Bloomsbury
# 99             H tel Crayon Rouge by Elegancia
# Name: Hotel_Name, Length: 100, dtype: object, 'bathtub': 0                           My Chelsea
# 1                             Colombia
# 2                     ME Milan Il Duca
# 3               Mercure Milano Regency
# 4                       Number Sixteen
#                     ...
# 95                   Hotel Atmospheres
# 96        Best Western Hotel St George
# 97                   Hotel 4 Barcelona
# 98    Holiday Inn London Oxford Circus
# 99          Gran Hotel Torre Catalunya
# Name: Hotel_Name, Length: 100, dtype: object, 'clean room': 0         Hotel degli Arcimboldi
# 1             Catalonia Catedral
# 2               The Lanesborough
# 3         IH Hotels Milano Gioia
# 4                 Catalonia Born
#                  ...
# 95             Art Hotel Navigli
# 96    Best Western Aulivia Op ra
# 97                 Op ra Marigny
# 98          Eurostars Monumental
# 99          Hotel Maison Ath n e
# Name: Hotel_Name, Length: 100, dtype: object}
# [['spacious', 'space'], ['couple room', 'couple room'], ['double bed', 'double bed'], ['leisure trip', 'leisure trip'], ['business trip', 'business'], ['deluxe', 'deluxe'], ['spa', 'spa'], ['gym', 'gym'], ['fine dining', 'dining'], ['bathtub', 'bathtub'], ['clean room', 'clean']]

# %%
import pickle

hotelData=pickle.load(open("hotelModel2.pkl","rb"))
hotelData.head()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pickle
# ----> 3 hotelData=pickle.load(open("hotelModel2.pkl","rb"))
#       4 hotelData.head()
#
# EOFError: Ran out of input

# %%
oldestDate=hotelData['ReviewDate'].min()
newestDate=hotelData['ReviewDate'].max()
print(oldestDate)
print(newestDate)
hotelData['isRecent']=hotelData['ReviewDate'].dt.year==2017
t=hotelData['isRecent'].sum()
f=len(hotelData)-t
print(t,f)
# Out:
# 2015-08-04 00:00:00
# 2017-08-03 00:00:00
# 156808 358930

# %%
hotelData.sample(5)
# Out:
#                                             Hotel_Address  Average_Score  \
# 508565  Whitcomb Street Trafalgar Square Westminster B...            8.4
# 112903  225 Edgware Road Westminster Borough London W2...            7.5
# 34416             11 Rue Du Temple 4th arr 75004 Paris FR            8.6
# 135833  3 Place du G n ral Koenig 17th arr 75017 Paris FR            7.1
# 512850  Wrights Lane Kensington and Chelsea London W8 ...            7.8
#
#         Reviewer_Score                                    Hotel_Name  \
# 508565             7.1  Thistle Trafalgar Square The Royal Trafalgar
# 112903             9.6                       Hilton London Metropole
# 34416              4.2                                     H tel Duo
# 135833             7.5                    Hyatt Regency Paris Etoile
# 512850             9.2                 Holiday Inn London Kensington
#
#                                           Positive_Review  \
# 508565                                           location
# 112903   i got a free upgraded room and free wifi in m...
# 34416     location was perfect for nearby sites to visit
# 135833                          checking in was a breeze
# 512850   lovely rooms very comfy bed great breakfast g...
#
#                                                      Tags  \
# 508565   leisure trip  couple  junior suite  stayed 1 ...
# 112903   business trip  solo traveler  king hilton gue...
# 34416    leisure trip  group  standard double room  st...
# 135833   leisure trip  family with young children  del...
# 512850   leisure trip  group  standard room  stayed 1 ...
#
#                                                     Words countries  Stars  \
# 508565   leisure trip  couple  junior suite  stayed 1 ...        UK      5
# 112903   business trip  solo traveler  king hilton gue...        UK      4
# 34416    leisure trip  group  standard double room  st...        FR      3
# 135833   leisure trip  family with young children  del...        FR      5
# 512850   leisure trip  group  standard room  stayed 1 ...        UK      5
#
#         Price                                        Amenities ReviewDate  \
# 508565   1100      [Swimming Pool, TV, Wifi, Air Conditioning] 2017-03-27
# 112903    900               [Wifi, Gym, BathTub, Parking, Spa] 2015-11-10
# 34416     290                           [BathTub, Fine Dining] 2017-01-01
# 135833   1010  [Swimming Pool, Fine Dining, Spa, BathTub, Gym] 2017-04-29
# 512850   1470      [Air Conditioning, Room Service, Spa, Wifi] 2017-03-27
#
#         isRecent
# 508565      True
# 112903     False
# 34416       True
# 135833      True
# 512850      True

# %%
import pickle

pickle.dump(hotelData,open("hotelModel.pkl","wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pickle
# ----> 3 pickle.dump(hotelData,open("hotelModelPickle.pkl","wb"))
#
# NameError: name 'hotelData' is not defined

# %%
import pickle

hotelData=pickle.load(open("hotelModel2.pkl","rb"))
hotelData.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#    Reviewer_Score   Hotel_Name  \
# 0             2.9  Hotel Arena
# 1             7.5  Hotel Arena
# 2             7.1  Hotel Arena
# 3             3.8  Hotel Arena
# 4             6.7  Hotel Arena
#
#                                      Positive_Review  \
# 0   only the park outside of the hotel was beauti...
# 1   no real complaints the hotel was great great ...
# 2   location was good and staff were ok it is cut...
# 3   great location in nice surroundings the bar a...
# 4    amazing location and building romantic setting
#
#                                                 Tags  \
# 0   leisure trip  couple  duplex double room  sta...
# 1   leisure trip  couple  duplex double room  sta...
# 2   leisure trip  family with young children  dup...
# 3   leisure trip  solo traveler  duplex double ro...
# 4   leisure trip  couple  suite  stayed 2 nights ...
#
#                                                Words countries  Stars  Price  \
# 0   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 1   leisure trip  couple  duplex double room  sta...        NL      5   1470
# 2   leisure trip  family with young children  dup...        NL      5   1470
# 3   leisure trip  solo traveler  duplex double ro...        NL      5   1470
# 4   leisure trip  couple  suite  stayed 2 nights ...        NL      5   1470
#
#                                Amenities ReviewDate  isRecent
# 0  [Air Conditioning, Fine Dining, Wifi] 2017-08-03      True
# 1  [Air Conditioning, Fine Dining, Wifi] 2017-08-03      True
# 2  [Air Conditioning, Fine Dining, Wifi] 2017-07-31      True
# 3  [Air Conditioning, Fine Dining, Wifi] 2017-07-31      True
# 4  [Air Conditioning, Fine Dining, Wifi] 2017-07-24      True

# %%
isrecent=[]

for i in range (len(hotelData)):
    n=random.randint(0,1)
    if(n==0):
        isrecent.append(True)
    else:
        isrecent.append(False)

print(isrecent)
# Out:
# [False, False, False, True, True, False, False, True, False, False, True, True, True, True, False, False, False, True, True, True, True, False, True, False, True, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, True, True, True, False, True, True, True, True, False, False, False, False, True, False, False, True, False, True, True, True, True, False, False, True, True, False, False, True, True, True, False, False, True, False, True, False, True, False, True, False, True, True, False, False, True, False, False, True, False, True, True, False, False, True, False, False, False, True, False, True, False, True, False, False, True, False, False, True, False, False, False, True, True, True, False, True, False, False, False, False, False, True, False, True, True, True, True, False, True, True, False, False, False, False, False, False, True, False, False, True, False, False, True, False, False, False, False, False, False, False, False, True, True, False, False, True, False, True, True, True, True, True, True, False, False, False, True, True, True, True, True, False, True, True, True, True, True, False, True, False, True, False, False, False, True, False, False, True, False, True, True, True, True, False, False, False, True, True, True, True, False, False, True, True, True, True, False, True, True, True, True, False, False, True, False, True, False, True, False, True, False, True, True, True, False, False, True, True, True, True, False, True, False, True, False, True, True, True, True, False, True, True, True, False, False, False, False, False, True, False, False, False, True, True, True, True, False, True, False, False, False, False, True, True, True, False, False, True, True, False, False, False, False, False, True, True, False, False, False, False, True, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, False, True, True, True, True, True, False, False, True, False, False, True, False, False, False, False, False, True, True, False, False, True, False, True, True, False, False, True, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, True, True, True, False, False, True, False, True, False, False, True, True, False, True, False, True, True, False, True, True, True, False, False, True, False, True, False, False, True, True, True, True, True, False, False, False, True, True, False, False, False, True, True, True, True, False, True, False, False, True, True, True, True, False, False, True, True, False, True, True, False, True, True, True, True, True, True, True, True, False, True, True, False, False, True, True, False, True, False, False, False, True, False, True, True, True, True, False, False, True, True, True, True, True, False, True, False, True, True, True, True, False, True, False, False, False, False, False, False, True, False, False, True, True, True, True, False, True, True, True, True, False, False, True, False, False, True, True, False, False, False, False, True, False, True, False, True, False, True, False, False, False, True, False, True, True, True, True, False, False, True, True, True, True, True, True, True, False, False, False, True, False, False, False, True, False, False, True, False, True, False, True, True, False, False, True, True, False, False, True, True, False, False, False, True, True, True, True, False, False, True, False, False, True, True, False, True, True, False, True, True, True, True, False, False, True, False, False, True, True, True, False, False, True, True, False, True, True, False, True, False, False, True, True, False, True, True, False, False, False, True, False, True, False, True, False, False, False, False, True, False, False, True, False, False, True, False, False, True, False, False, True, False, False, True, True, True, True, False, False, True, False, True, True, False, True, True, False, False, False, True, True, False, True, False, Tru ...

# %%
hotelData['isRecent']=isrecent

# %%
hotelData.sample()
# Out:
#                                          Hotel_Address  Average_Score  \
# 222500  60 Pentonville Road Islington London N1 9LA UK            8.6
#
#         Reviewer_Score                             Hotel_Name Positive_Review  \
# 222500             5.0  DoubleTree by Hilton London Islington       bar area
#
#                                                      Tags  \
# 222500   leisure trip  couple  double room  stayed 3 n...
#
#                                                     Words countries  Stars  \
# 222500   leisure trip  couple  double room  stayed 3 n...        UK      3
#
#         Price                                 Amenities ReviewDate  isRecent
# 222500    440  [BathTub, Air Conditioning, Fine Dining] 2016-08-23      True

# %%
import pickle

pickle.dump(hotelData,open("hotelModel2.pkl","wb"))
